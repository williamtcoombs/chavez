# %%
# chavez & coombs 
# 13976(v1).ipynb
# 2020-08-27
# data management for deltek 13976

# %% [markdown]
# Steps:
# 1. Download the deltek data as an Excel file
# 2. Save 'AP2 Regular & OT Hours for Adv by CCC_#505ap.xlsx' on U:\
# 3. Run the code below

# %%
# to determine conda version or conda and python versions, from a cmd window at the ">" prompt:
# > conda -V
#   conda 4.2.9
# > python --version
#   Python 3.5.2 :: Anaconda 4.2.0 (64-bit)

# %%
# import modules
import pandas
import os
import sys
import gc

# %%
# current working directory
print(os.getcwd())
# Out:
# \\ain2\dfsroot\userdata48\willitc0\Data

# %% [markdown]
# "read_csv() vs read_excel() in pandas: When to use which and why" by Ashwin A. Vardhan
#
# Have you ever wondered if that excel file that you have, can be made to read faster instead of sitting idle for 10 minutes while your code scans through it? I’ll try to answer it here with a personal experience of mine.
#
# So, I was performing some operations on an excel file using pandas, whose dimensions were 509579 x 240, and it had a size of 295 MB. However, reading that file took about 528 seconds (average over 10 iterations), whereas, on converting it to csv and reading it (using pandas) took just 13 seconds (again, average over 10 iterations), which is an improvement of about 40 times. As you can observe, the file was too huge, and read_excel is just slower in performance. This has been mentioned on stackoverflow too.
#
# So, when will you actually need to convert an excel file to csv before processing it? Usually, if your excel file is small (~100,000 rows, ~50 columns), there won’t be much of a performance issue, unless, you need to run that process very frequently, because, that small delay may get compunded and bite you! But, if your excel file is massive, and you need to process it frequently (or not), it’s better to first convert the excel into a csv, and voila! see the magic happen.

# %%
# read data
# df = pd.read_csv (r'Path where the CSV file is stored\File name.csv')
data = pandas.read_excel (r'U:\AP2 Regular & OT Hours for Adv by CCC_#505ap.xlsx')

# %%
# Pandas has the following data types:
#    object
#    int64
#    float64
#    bool
#    datetime64
#    timedelta[ns]
#    category

# %%
# check metadata
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231795 entries, 0 to 231794
# Data columns (total 23 columns):
# User                 231795 non-null object
# User Id              231795 non-null object
# Work Date            231795 non-null datetime64[ns]
# Month                231795 non-null datetime64[ns]
# Description          231795 non-null object
# REF ID               231795 non-null int64
# CLIN                 231795 non-null object
# WBS                  39929 non-null object
# TASK                 231795 non-null object
# TPID                 231795 non-null object
# ProjNo               231795 non-null object
# WB2                  231795 non-null object
# Project Id           231795 non-null object
# Pay Type             231795 non-null object
# Corporation          231795 non-null object
# Company Name         231795 non-null object
# Approver             231795 non-null object
# Status               231795 non-null object
# Straight             231795 non-null float64
# Overtime             231795 non-null float64
# Total                231795 non-null float64
# Date Time Entered    231795 non-null datetime64[ns]
# Org Id               231761 non-null object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(16)
# memory usage: 40.7+ MB

# %%
# trim data
df = pandas.DataFrame(data, columns= ['User','Work Date', 'Description', 'TPID', 'Straight', 'Overtime', 'Total'])
df.head(2)
# Out:
#                  User  Work Date              Description  \
# 0  SCHNEIDER, LAURA E 2020-07-14  Standby Only - COVID-19
# 1  SCHNEIDER, LAURA E 2020-07-17  Standby Only - COVID-19
#
#                    TPID  Straight  Overtime  Total
# 0  13976.00.01.0111.999       0.0       0.0    0.0
# 1  13976.00.01.0111.999       0.0       0.0    0.0

# %%
# create option year column based on work date
# df1['date'] = pandas.to_datetime(df1['date'])
oy0_mask = (df['Work Date']>='2009-08-03') & (df['Work Date']<='2010-08-02')
oy1_mask = (df['Work Date']>='2010-08-03') & (df['Work Date']<='2011-08-02')
oy2_mask = (df['Work Date']>='2011-08-03') & (df['Work Date']<='2012-08-02')
oy3_mask = (df['Work Date']>='2012-08-03') & (df['Work Date']<='2013-08-02')
oy4_mask = (df['Work Date']>='2013-08-03') & (df['Work Date']<='2014-08-02')
oy5_mask = (df['Work Date']>='2014-08-03') & (df['Work Date']<='2015-08-02')
oy6_mask = (df['Work Date']>='2015-08-03') & (df['Work Date']<='2016-08-02')
oy7_mask = (df['Work Date']>='2016-08-03') & (df['Work Date']<='2017-08-02')
oy8_mask = (df['Work Date']>='2017-08-03') & (df['Work Date']<='2018-08-02')
oy9_mask = (df['Work Date']>='2018-08-03') & (df['Work Date']<='2019-08-02')
bridge_mask = (df['Work Date']>='2019-08-03')

df.loc[oy0_mask, 'OptYr'] = 'OY0'
df.loc[oy1_mask, 'OptYr'] = 'OY1'
df.loc[oy2_mask, 'OptYr'] = 'OY2'
df.loc[oy3_mask, 'OptYr'] = 'OY3'
df.loc[oy4_mask, 'OptYr'] = 'OY4'
df.loc[oy5_mask, 'OptYr'] = 'OY5'
df.loc[oy6_mask, 'OptYr'] = 'OY6'
df.loc[oy7_mask, 'OptYr'] = 'OY7'
df.loc[oy8_mask, 'OptYr'] = 'OY8'
df.loc[oy9_mask, 'OptYr'] = 'OY9'
df.loc[bridge_mask, 'OptYr'] = 'OY.'

df
# Out:
#                       User  Work Date              Description  \
# 0       SCHNEIDER, LAURA E 2020-07-14  Standby Only - COVID-19
# 1       SCHNEIDER, LAURA E 2020-07-17  Standby Only - COVID-19
# 2       SCHNEIDER, LAURA E 2020-07-20  Standby Only - COVID-19
# 3       SCHNEIDER, LAURA E 2020-08-07  Standby Only - COVID-19
# 4       SCHNEIDER, LAURA E 2020-08-10        Software Services
# 5       SCHNEIDER, LAURA E 2020-08-10        Software Services
# 6       SCHNEIDER, LAURA E 2020-08-24        Software Services
# 7       SCHNEIDER, LAURA E 2020-07-15        Software Services
# 8       SCHNEIDER, LAURA E 2020-07-23  Standby Only - COVID-19
# 9       SCHNEIDER, LAURA E 2020-07-28        Software Services
# 10      SCHNEIDER, LAURA E 2020-07-31        Software Services
# 11      SCHNEIDER, LAURA E 2020-08-25        Software Services
# 12      SCHNEIDER, LAURA E 2020-07-30        Software Services
# 13      SCHNEIDER, LAURA E 2020-07-13  Standby Only - COVID-19
# 14      SCHNEIDER, LAURA E 2020-07-16  Standby Only - COVID-19
# 15      SCHNEIDER, LAURA E 2020-07-24  Standby Only - COVID-19
# 16      SCHNEIDER, LAURA E 2020-08-05        Software Services
# 17      SCHNEIDER, LAURA E 2020-08-13        Software Services
# 18      SCHNEIDER, LAURA E 2020-07-14        Software Services
# 19      SCHNEIDER, LAURA E 2020-07-17        Software Services
# 20      SCHNEIDER, LAURA E 2020-07-21  Standby Only - COVID-19
# 21      SCHNEIDER, LAURA E 2020-07-22  Standby Only - COVID-19
# 22      SCHNEIDER, LAURA E 2020-08-06  Standby Only - COVID-19
# 23      SCHNEIDER, LAURA E 2020-08-12        Software Services
# 24      SCHNEIDER, LAURA E 2020-08-14        Software Services
# 25      SCHNEIDER, LAURA E 2020-07-13        Software Services
# 26      SCHNEIDER, LAURA E 2020-07-15  Standby Only - COVID-19
# 27      SCHNEIDER, LAURA E 2020-07-16        Software Services
# 28      SCHNEIDER, LAURA E 2020-07-29        Software Services
# 29      SCHNEIDER, LAURA E 2020-07-27        Software Services
# ...                    ...        ...                      ...
# 231765       Stokes, Duane 2019-08-14              O&M Support
# 231766       Stokes, Duane 2019-08-29              O&M Support
# 231767       Stokes, Duane 2019-09-10              O&M Support
# 231768       Stokes, Duane 2019-09-17              O&M Support
# 231769       Stokes, Duane 2019-09-19              O&M Support
# 231770       Stokes, Duane 2019-09-25              O&M Support
# 231771       Stokes, Duane 2019-09-27              O&M Support
# 231772       Stokes, Duane 2019-08-13              O&M Support
# 231773       Stokes, Duane 2019-08-20              O&M Support
# 231774       Stokes, Duane 2019-08-21              O&M Support
# 231775       Stokes, Duane 2019-09-24              O&M Support
# 231776       Stokes, Duane 2019-10-01              O&M Support
# 231777       Stokes, Duane 2019-10-07              O&M Support
# 231778       Stokes, Duane 2019-10-08              O&M Support
# 231779       Stokes, Duane 2019-09-03              O&M Support
# 231780       Stokes, Duane 2019-09-05              O&M Support
# 231781       Stokes, Duane 2019-09-11              O&M Support
# 231782       Stokes, Duane 2019-09-16              O&M Support
# 231783       Stokes, Duane 2019-09-23              O&M Support
# 231784       Stokes, Duane 2019-10-04              O&M Support
# 231785       Stokes, Duane 2019-10-10              O&M Support
# 231786       Stokes, Duane 2019-10-11              O&M Support
# 231787       Stokes, Duane 2019-08-06              O&M Support
# 231788       Stokes, Duane 2019-08-08              O&M Support
# 231789       Stokes, Duane 2019-08-19              O&M Support
# 231790       Stokes, Duane 2019-08-27              O&M Support
# 231791       Stokes, Duane 2019-09-12              O&M Support
# 231792       Stokes, Duane 2019-09-18              O&M Support
# 231793       Stokes, Duane 2019-10-02              O&M Support
# 231794       Stokes, Duane 2019-10-09              O&M Support
#
#                         TPID  Straight  Overtime  Total OptYr
# 0       13976.00.01.0111.999       0.0       0.0    0.0   OY.
# 1       13976.00.01.0111.999       0.0       0.0    0.0   OY.
# 2       13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 3       13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 4       13976.00.00.0011.509       0.0       0.0    0.0   OY.
# 5       13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 6       13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 7       13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 8       13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 9       13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 10      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 11      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 12      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 13      13976.00.01.0111.999       0.0       0.0    0.0   OY.
# 14      13976.00.01.0111.999       0.0       0.0    0.0   OY.
# 15      13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 16      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 17      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 18      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 19      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 20      13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 21      13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 22      13976.00.01.0111.999       8.0       0.0    8.0   OY.
# 23      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 24      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 25      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 26      13976.00.01.0111.999       0.0       0.0    0.0   OY.
# 27      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 28      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# 29      13976.00.01.0111.509       8.0       0.0    8.0   OY.
# ...                      ...       ...       ...    ...   ...
# 231765  13976.00.00.0007.000       9.5       0.0    9.5   OY.
# 231766  13976.00.00.0007.000      10.5       0.0   10.5   OY.
# 231767  13976.00.00.0007.000       9.5       0.0    9.5   OY.
# 231768  13976.00.00.0007.000      11.0       0.0   11.0   OY.
# 231769  13976.00.00.0007.000       7.0       0.0    7.0   OY.
# 231770  13976.00.00.0007.000       9.0       0.0    9.0   OY.
# 231771  13976.00.00.0007.000      11.0       0.0   11.0   OY.
# 231772  13976.00.00.0007.000       9.0       0.0    9.0   OY.
# 231773  13976.00.00.0007.000       9.0       0.0    9.0   OY.
# 231774  13976.00.00.0007.000      10.0       0.0   10.0   OY.
# 231775  13976.00.00.0007.000      11.5       0.0   11.5   OY.
# 231776  13976.00.00.0007.000       1.5       0.0    1.5   OY.
# 231777  13976.00.00.0007.000       8.5       0.0    8.5   OY.
# 231778  13976.00.00.0007.000       5.5       0.0    5.5   OY.
# 231779  13976.00.00.0007.000      10.0       0.0   10.0   OY.
# 231780  13976.00.00.0007.000      13.0       0.0   13.0   OY.
# 231781  13976.00.00.0007.000      10.0       0.0   10.0   OY.
# 231782  13976.00.00.0007.000       8.0       0.0    8.0   OY.
# 231783  13976.00.00.0007.000       8.5       0.0    8.5   OY.
# 231784  13976.00.00.0007.000       6.0       0.0    6.0   OY.
# 231785  13976.00.00.0007.000       8.0       0.0    8.0   OY.
# 231786  13976.00.00.0007.000       6.0       0.0    6.0   OY.
# 231787  13976.00.00.0007.000       9.5       0.0    9.5   OY.
# 231788  13976.00.00.0007.000      10.0       0.0   10.0   OY.
# 231789  13976.00.00.0007.000       6.0       0.0    6.0   OY.
# 231790  13976.00.00.0007.000       6.5       0.0    6.5   OY.
# 231791  13976.00.00.0007.000      11.5       0.0   11.5   OY.
# 231792  13976.00.00.0007.000       7.0       0.0    7.0   OY.
# 231793  13976.00.00.0007.000       2.0       0.0    2.0   OY.
# 231794  13976.00.00.0007.000      10.5       0.0   10.5   OY.
#
# [231795 rows x 8 columns]

# %%
# count number of rows associated with different values of id
df['OptYr'].value_counts()
# Out:
# OY.    231787
# OY9         8
# Name: OptYr, dtype: int64

# %%
df[df['OptYr'] == 'OY9']
# Out:
#                            User  Work Date           Description  \
# 8118              RICE, SCOTT C 2019-08-01     Overhead Req Mgmt
# 62738   RONEY-DEMARY, MELISSA W 2019-08-02     Software Services
# 105030           JACKSON, NAKIA 2019-08-02     Software Services
# 110635           BARNES, RONELL 2019-08-02     Software Services
# 129997         MIRANDO, JAMES A 2019-08-01  Warehouse Operations
# 130102         MIRANDO, JAMES A 2019-08-02  Warehouse Operations
# 191843             Sykes, Loyda 2019-08-02  Warehouse Operations
# 192029             Sykes, Loyda 2019-08-01  Warehouse Operations
#
#                         TPID  Straight  Overtime  Total OptYr
# 8118    13976.00.00.0012.OH2       0.0       0.0    0.0   OY9
# 62738   13976.00.00.0011.509       0.0       0.0    0.0   OY9
# 105030  13976.00.00.0011.509       0.0       0.0    0.0   OY9
# 110635  13976.00.00.0011.509       0.0       0.0    0.0   OY9
# 129997  13976.00.00.0011.516       0.0       0.0    0.0   OY9
# 130102  13976.00.00.0011.516       0.0       0.0    0.0   OY9
# 191843  13976.00.00.0011.516       0.0       0.0    0.0   OY9
# 192029  13976.00.00.0011.516       0.0       0.0    0.0   OY9

# %%
# check metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231795 entries, 0 to 231794
# Data columns (total 8 columns):
# User           231795 non-null object
# Work Date      231795 non-null datetime64[ns]
# Description    231795 non-null object
# TPID           231795 non-null object
# Straight       231795 non-null float64
# Overtime       231795 non-null float64
# Total          231795 non-null float64
# OptYr          231795 non-null object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 14.1+ MB

# %%
# check dataframe dimensions (rows x columns)
df.shape
# Out:
# (231795, 8)

# %%
# format data
# round floating numbers to two decimal places in python pandas 
pandas.options.display.float_format = '{:.2f}'.format

# %%
# check data types
df.dtypes
# Out:
# User                   object
# Work Date      datetime64[ns]
# Description            object
# TPID                   object
# Straight              float64
# Overtime              float64
# Total                 float64
# OptYr                  object
# dtype: object

# %%
# add clin placeholder column
df.insert(3, 'CLIN', '')
df.head(3)
# Out:
#                  User  Work Date              Description CLIN  \
# 0  SCHNEIDER, LAURA E 2020-07-14  Standby Only - COVID-19
# 1  SCHNEIDER, LAURA E 2020-07-17  Standby Only - COVID-19
# 2  SCHNEIDER, LAURA E 2020-07-20  Standby Only - COVID-19
#
#                    TPID  Straight  Overtime  Total OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00   OY.

# %%
# add wbs placeholder column
df.insert(4, 'WBS', '')
df.head(3)
# Out:
#                  User  Work Date              Description CLIN WBS  \
# 0  SCHNEIDER, LAURA E 2020-07-14  Standby Only - COVID-19
# 1  SCHNEIDER, LAURA E 2020-07-17  Standby Only - COVID-19
# 2  SCHNEIDER, LAURA E 2020-07-20  Standby Only - COVID-19
#
#                    TPID  Straight  Overtime  Total OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00   OY.

# %%
# add SR placeholder column
df.insert(9, 'SR_temp', '')
df.head(3)
# Out:
#                  User  Work Date              Description CLIN WBS  \
# 0  SCHNEIDER, LAURA E 2020-07-14  Standby Only - COVID-19
# 1  SCHNEIDER, LAURA E 2020-07-17  Standby Only - COVID-19
# 2  SCHNEIDER, LAURA E 2020-07-20  Standby Only - COVID-19
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00           OY.

# %%
# check metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231795 entries, 0 to 231794
# Data columns (total 11 columns):
# User           231795 non-null object
# Work Date      231795 non-null datetime64[ns]
# Description    231795 non-null object
# CLIN           231795 non-null object
# WBS            231795 non-null object
# TPID           231795 non-null object
# Straight       231795 non-null float64
# Overtime       231795 non-null float64
# Total          231795 non-null float64
# SR_temp        231795 non-null object
# OptYr          231795 non-null object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 19.5+ MB

# %%
# column a
df['User'].head(2)
# Out:
# 0    SCHNEIDER, LAURA E
# 1    SCHNEIDER, LAURA E
# Name: User, dtype: object

# %%
# column b
# modify workdate format
df['Work Date'] = pandas.to_datetime(df['Work Date']).dt.strftime('%Y-%m-%d')
df.head(2)
# Out:
#                  User   Work Date              Description CLIN WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.

# %%
# column c
df['Description'].head(2)
# Out:
# 0    Standby Only - COVID-19
# 1    Standby Only - COVID-19
# Name: Description, dtype: object

# %%
# column d
# get clin from tpid
df['CLIN'] = data.TPID.str.split(".", expand=True,)[3]
df.head(2)
# Out:
#                  User   Work Date              Description  CLIN WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.

# %%
# column e
# get wbs from tpid
df['WBS'] = data.TPID.str.split(".", expand=True,)[4]
df.head(2)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.

# %%
# column f
# tpid
df.head(2)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.

# %%
# save syntax to modfiy column order
# df = df[['User', 'Work Date', 'Description', 'CLIN', 'WBS', 'TPID', 'Straight', 'Overtime', 'Total', 'SR', 'OptYr']]

# %%
# check metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231795 entries, 0 to 231794
# Data columns (total 11 columns):
# User           231795 non-null object
# Work Date      231795 non-null object
# Description    231795 non-null object
# CLIN           231795 non-null object
# WBS            231795 non-null object
# TPID           231795 non-null object
# Straight       231795 non-null float64
# Overtime       231795 non-null float64
# Total          231795 non-null float64
# SR_temp        231795 non-null object
# OptYr          231795 non-null object
# dtypes: float64(3), object(8)
# memory usage: 19.5+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231795 entries, 0 to 231794
# Data columns (total 23 columns):
# User                 231795 non-null object
# User Id              231795 non-null object
# Work Date            231795 non-null datetime64[ns]
# Month                231795 non-null datetime64[ns]
# Description          231795 non-null object
# REF ID               231795 non-null int64
# CLIN                 231795 non-null object
# WBS                  39929 non-null object
# TASK                 231795 non-null object
# TPID                 231795 non-null object
# ProjNo               231795 non-null object
# WB2                  231795 non-null object
# Project Id           231795 non-null object
# Pay Type             231795 non-null object
# Corporation          231795 non-null object
# Company Name         231795 non-null object
# Approver             231795 non-null object
# Status               231795 non-null object
# Straight             231795 non-null float64
# Overtime             231795 non-null float64
# Total                231795 non-null float64
# Date Time Entered    231795 non-null datetime64[ns]
# Org Id               231761 non-null object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(16)
# memory usage: 40.7+ MB

# %%
# what size are some of the objects?
print('data', sys.getsizeof(data))
print('df', sys.getsizeof(df))
print('Straight', sys.getsizeof(df['Straight']))
print('TPID', sys.getsizeof(df['TPID']))
# Out:
# data 252265296
# df 130662941
# Straight 1854464
# TPID 18167751

# %%
# delete original dataframe to free up memory
del[data]

# %%
# save delete datafrome column syntax
# df = df.drop('Company Name', 1)

# %%
gc.collect()
# Out:
# 73

# %%
# add tpid character count column
df['tpid_length'] = df['TPID'].str.len()
df.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr  tpid_length
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 2  13976.00.01.0111.999      8.00      0.00   8.00           OY.           20

# %%
df['tpid_length'].value_counts()
# Out:
# 20    191866
# 28     39929
# Name: tpid_length, dtype: int64

# %%
# where tpid_length = 20
df[df['tpid_length'] == 20].head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr  tpid_length
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 2  13976.00.01.0111.999      8.00      0.00   8.00           OY.           20

# %%
# where tpid_length = 28
df[df['tpid_length'] == 28].head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_temp OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00           OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00           OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00           OY.
#
#       tpid_length
# 69             28
# 2427           28
# 2428           28

# %%
# filter on tpid_length
df20 = df[df['tpid_length'] == 20]
df20.shape
# Out:
# (191866, 12)

# %%
# filter on tpid_length
df28 = df[df['tpid_length'] == 28]
df28.shape
# Out:
# (39929, 12)

# %%
df.shape
# Out:
# (231795, 12)

# %%
del[df]
gc.collect()
# Out:
# 398

# %%
df20.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp OptYr  tpid_length
# 0  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 1  13976.00.01.0111.999      0.00      0.00   0.00           OY.           20
# 2  13976.00.01.0111.999      8.00      0.00   8.00           OY.           20

# %%
# SR column
df20.insert(10, 'SR', 'SR-0000000')
df20.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total SR_temp          SR OptYr  \
# 0  13976.00.01.0111.999      0.00      0.00   0.00          SR-0000000   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00          SR-0000000   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00          SR-0000000   OY.
#
#    tpid_length
# 0           20
# 1           20
# 2           20

# %%
# delete SR_temp column
df20 = df20.drop('SR_temp', 1)
df20.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total          SR OptYr  \
# 0  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00  SR-0000000   OY.
#
#    tpid_length
# 0           20
# 1           20
# 2           20

# %%
df28.head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_temp OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00           OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00           OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00           OY.
#
#       tpid_length
# 69             28
# 2427           28
# 2428           28

# %%
# get sr from tpid
df28['SR_no'] = df28.TPID.str.split(".", expand=True,)[5]
df28.head(3)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_temp OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00           OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00           OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00           OY.
#
#       tpid_length    SR_no
# 69             28  5913720
# 2427           28  5522685
# 2428           28  5364379

# %%
df28.insert(10, 'SR_prefix', 'SR-')
df28.head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_temp  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00
#
#      SR_prefix OptYr  tpid_length    SR_no
# 69         SR-   OY.           28  5913720
# 2427       SR-   OY.           28  5522685
# 2428       SR-   OY.           28  5364379

# %%
df28['SR'] = df28['SR_prefix'] + df28['SR_no']
df28.head(3)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_temp  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00
#
#      SR_prefix OptYr  tpid_length    SR_no          SR
# 69         SR-   OY.           28  5913720  SR-5913720
# 2427       SR-   OY.           28  5522685  SR-5522685
# 2428       SR-   OY.           28  5364379  SR-5364379

# %%
# delete SR_temp column
df28 = df28.drop('SR_temp', 1)
df28.head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total SR_prefix OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00       SR-   OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00       SR-   OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00       SR-   OY.
#
#       tpid_length    SR_no          SR
# 69             28  5913720  SR-5913720
# 2427           28  5522685  SR-5522685
# 2428           28  5364379  SR-5364379

# %%
# delete SR_prefix column
df28 = df28.drop('SR_prefix', 1)
df28.head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00   OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00   OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00   OY.
#
#       tpid_length    SR_no          SR
# 69             28  5913720  SR-5913720
# 2427           28  5522685  SR-5522685
# 2428           28  5364379  SR-5364379

# %%
# delete SR_no column
df28 = df28.drop('SR_no', 1)
df28.head(3)
# Out:
#                        User   Work Date               Description  CLIN  WBS  \
# 69    CHERRY, CHRISTOPHER H  2020-08-24  Installation-Fixed Price  0114  000
# 2427        TIMMONS, CARL A  2019-08-22  Installation-Fixed Price  0014  000
# 2428        TIMMONS, CARL A  2019-09-12  Installation-Fixed Price  0014  000
#
#                               TPID  Straight  Overtime  Total OptYr  \
# 69    13976.00.01.0114.000.5913720      8.00      0.00   8.00   OY.
# 2427  13976.00.00.0014.000.5522685      8.00      0.00   8.00   OY.
# 2428  13976.00.00.0014.000.5364379      8.00      0.00   8.00   OY.
#
#       tpid_length          SR
# 69             28  SR-5913720
# 2427           28  SR-5522685
# 2428           28  SR-5364379

# %%
# standardize column order
df20 = df20[['User', 'Work Date', 'Description', 'CLIN', 'WBS', 'TPID', 'Straight', 'Overtime', 'Total', 'SR', 'OptYr', 'tpid_length']]
df28 = df28[['User', 'Work Date', 'Description', 'CLIN', 'WBS', 'TPID', 'Straight', 'Overtime', 'Total', 'SR', 'OptYr', 'tpid_length']]

# %%
# concatenate vertical dataframes
df = pandas.concat([df20, df28], axis=0)

# %%
df20.shape
# Out:
# (191866, 12)

# %%
df28.shape
# Out:
# (39929, 12)

# %%
# check columns
df.shape
# Out:
# (231795, 12)

# %%
del[df20, df28]

# %%
gc.collect()
# Out:
# 308

# %%
# check metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231795 entries, 0 to 231751
# Data columns (total 12 columns):
# User           231795 non-null object
# Work Date      231795 non-null object
# Description    231795 non-null object
# CLIN           231795 non-null object
# WBS            231795 non-null object
# TPID           231795 non-null object
# Straight       231795 non-null float64
# Overtime       231795 non-null float64
# Total          231795 non-null float64
# SR             231795 non-null object
# OptYr          231795 non-null object
# tpid_length    231795 non-null int64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 23.0+ MB

# %%
# data check
df.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total          SR OptYr  \
# 0  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00  SR-0000000   OY.
#
#    tpid_length
# 0           20
# 1           20
# 2           20

# %%
# delete tpid_length column
df = df.drop('tpid_length', 1)
df.head(3)
# Out:
#                  User   Work Date              Description  CLIN  WBS  \
# 0  SCHNEIDER, LAURA E  2020-07-14  Standby Only - COVID-19  0111  999
# 1  SCHNEIDER, LAURA E  2020-07-17  Standby Only - COVID-19  0111  999
# 2  SCHNEIDER, LAURA E  2020-07-20  Standby Only - COVID-19  0111  999
#
#                    TPID  Straight  Overtime  Total          SR OptYr
# 0  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 1  13976.00.01.0111.999      0.00      0.00   0.00  SR-0000000   OY.
# 2  13976.00.01.0111.999      8.00      0.00   8.00  SR-0000000   OY.

# %%
df.to_excel (r'U:\AP2 Regular & OT Hours for Adv by CCC_#505ap-modified.xlsx', index = False, header=True)
